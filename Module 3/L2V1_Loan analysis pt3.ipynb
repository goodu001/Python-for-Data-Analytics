# %% [markdown]
# # Loan analysis pt. 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("loan_data.csv")

# %%
states = ["DC", "AK", "HI"]
filtered_df = df[df['state'].isin(states)]

# %%
grouped_data = filtered_df.groupby(['state', "grade"])['loan_amount'].mean() # order matters
grouped_data.unstack().plot(kind='bar')
plt.show()

# %%
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade"
)
plt.show()

# %%
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade"
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.show()

# %%
sns.barplot(
    filtered_df,
    x="state",
    y="interest_rate",
    hue="grade",
    estimator=np.max
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.show()

# %%
sns.set_theme()
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade"
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.show()

# %%
sns.set_theme(style="white")
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade"
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.show()

# %%
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade",
    palette="Blues"
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.show()

# %%
sns.barplot(
    filtered_df,
    x="state",
    y="loan_amount",
    hue="grade",
    palette="RdYlGn_r"
)
plt.xlabel("State")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by State and Grade")
plt.legend(title="Grade", bbox_to_anchor=(1,1))
plt.savefig("interest_rates_graph.png")

# %%
sns.boxplot(df, x="interest_rate")
plt.show()

# %%
sns.boxplot(df, y="interest_rate")
plt.title("Distribution of Interest Rate", fontsize=16, fontweight="bold")
plt.ylabel("Interest Rate", fontsize=14)
sns.despine(bottom=True)
plt.show()

# %%
sns.boxplot(df, x="grade", y="interest_rate", palette="RdYlGn_r")
plt.title("Distribution of Interest Rate", fontsize=16, fontweight="bold")
plt.ylabel("Interest Rate", fontsize=14)
sns.despine()
plt.grid(axis="y", linestyle="--")
plt.show()
# Out:
# /tmp/ipykernel_174/992613408.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df, x="grade", y="interest_rate", palette="RdYlGn_r")

# %%
sns.boxplot(df, hue="grade", y="interest_rate", palette="RdYlGn_r")
plt.title("Distribution of Interest Rate", fontsize=16, fontweight="bold")
plt.ylabel("Interest Rate", fontsize=14)
sns.despine()
plt.grid(axis="y", linestyle="--")
plt.show()

# %%
plt.figure(figsize=(8, 6)) # in inches, default 6.4x4.8
sns.boxplot(df, x="grade", y="interest_rate", palette="RdYlGn_r")
plt.title("Distribution of Interest Rate", fontsize=16, fontweight="bold")
plt.ylabel("Interest Rate", fontsize=14)
sns.despine()
plt.grid(axis="y", linestyle="--")
plt.show()
# Out:
# /tmp/ipykernel_174/316860509.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df, x="grade", y="interest_rate", palette="RdYlGn_r")

# %%
sns.histplot(df, x="loan_amount")
plt.show()

# %%
sns.histplot(df, x="loan_amount", color="RosyBrown")
plt.title("Distribution of Loan Amount", fontsize=16, fontweight="bold")
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
sns.histplot(df, x="loan_amount", color="RosyBrown", bins=30)
plt.title("Distribution of Loan Amount", fontsize=16, fontweight="bold")
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
sns.histplot(df, x="loan_amount", color="RosyBrown", binwidth=5000)
plt.title("Distribution of Loan Amount", fontsize=16, fontweight="bold")
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(visible=True) # doesn't work
plt.show()

# %%
sns.set_style("ticks")
sns.histplot(df, x="loan_amount", color="RosyBrown", binwidth=5000)
plt.title("Distribution of Loan Amount", fontsize=16, fontweight="bold")
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
sns.histplot(df, x="loan_amount", color="RosyBrown", binwidth=5000, kde=True)
plt.title("Distribution of Loan Amount", fontsize=16, fontweight="bold")
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
# Selecting the relevant columns for correlation
correlation_features = [
    'emp_length', 'debt_to_income', 'annual_income', 'open_credit_lines', 
    'total_credit_limit', 'total_credit_utilized', 'total_debit_limit', 
    'loan_amount', 'interest_rate', 'installment', 'balance', 'paid_interest'
]

# Compute the correlation matrix
correlation_table = df[correlation_features].corr()

# Create a custom colormap
custom_cmap = sns.diverging_palette(240, 10, as_cmap=True)  # 240 is blue, 10 is red

# Create a heatmap with the custom colormap
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_table, 
            annot=True, 
            fmt=".2f", 
            cmap=custom_cmap,
            center=0,  # This ensures white is at 0
            vmin=-1,   # Force the scale from -1 to 1
            vmax=1,
            cbar_kws={"shrink": .8})

plt.title('Correlation Heatmap of Loan Features')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %%
correlation_table
# Out:
#                        emp_length  debt_to_income  annual_income  \
# emp_length               1.000000        0.017722       0.117680
# debt_to_income           0.017722        1.000000      -0.177448
# annual_income            0.117680       -0.177448       1.000000
# open_credit_lines        0.079097        0.213761       0.180854
# total_credit_limit       0.141088        0.080848       0.546688
# total_credit_utilized    0.029949        0.234977       0.386707
# total_debit_limit        0.083761        0.075303       0.327736
# loan_amount              0.103392        0.050399       0.369342
# interest_rate           -0.006981        0.118798      -0.110327
# installment              0.081590        0.065365       0.356356
# balance                  0.097132        0.045418       0.335160
# paid_interest            0.065057        0.104210       0.202625
#
#                        open_credit_lines  total_credit_limit  \
# emp_length                      0.079097            0.141088
# debt_to_income                  0.213761            0.080848
# annual_income                   0.180854            0.546688
# open_credit_lines               1.000000            0.305617
# total_credit_limit              0.305617            1.000000
# total_credit_utilized           0.401110            0.483828
# total_debit_limit               0.440965            0.387536
# loan_amount                     0.166330            0.288242
# interest_rate                   0.006714           -0.148337
# installment                     0.157172            0.245758
# balance                         0.145561            0.260492
# paid_interest                   0.116069            0.109863
#
#                        total_credit_utilized  total_debit_limit  loan_amount  \
# emp_length                          0.029949           0.083761     0.103392
# debt_to_income                      0.234977           0.075303     0.050399
# annual_income                       0.386707           0.327736     0.369342
# open_credit_lines                   0.401110           0.440965     0.166330
# total_credit_limit                  0.483828           0.387536     0.288242
# total_credit_utilized               1.000000           0.284368     0.218837
# total_debit_limit                   0.284368           1.000000     0.349074
# loan_amount                         0.218837           0.349074     1.000000
# interest_rate                       0.003542          -0.265748     0.047447
# installment                         0.213650           0.319035     0.941512
# balance                             0.192534           0.309142     0.938655
# paid_interest                       0.133500           0.093378     0.713509
#
#                        interest_rate  installment   balance  paid_interest
# emp_length                 -0.006981     0.081590  0.097132       0.065057
# debt_to_income              0.118798     0.065365  0.045418       0.104210
# annual_income              -0.110327     0.356356  0.335160       0.202625
# open_credit_lines           0.006714     0.157172  0.145561       0.116069
# total_credit_limit         -0.148337     0.245758  0.260492       0.109863
# total_credit_utilized       0.003542     0.213650  0.192534       0.133500
# total_debit_limit          -0.265748     0.319035  0.309142       0.093378
# loan_amount                 0.047447     0.941512  0.938655       0.713509
# interest_rate               1.000000     0.084006  0.047367       0.524692
# installment                 0.084006     1.000000  0.867745       0.690433
# balance                     0.047367     0.867745  1.000000       0.710018
# paid_interest               0.524692     0.690433  0.710018       1.000000

# %%
# Create a violin plot with built-in 'box' for internal statistics
plt.figure(figsize=(8, 8))
sns.violinplot(df, x='grade', y='loan_amount', inner='box', palette='RdYlGn_r')

# Add a grid on the y axis
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.title('Distribution of Loan Amounts by Loan Grade with Internal Box')
plt.xlabel('Loan Grade')
plt.ylabel('Loan Amount')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_174/417292121.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='grade', y='loan_amount', inner='box', palette='RdYlGn_r')

# %%
# Creating a regression plot for paid interest versus loan amount
plt.figure(figsize=(8, 6))
sns.regplot(df, x='loan_amount', 
            y='paid_interest', 
            scatter_kws={"color": "slateblue"}, 
            line_kws={"color": "black"})

# Set title and labels
plt.title('Regression of Paid Interest on Loan Amount', fontsize=16, fontweight="bold")
plt.xlabel('Loan Amount ($)')
plt.ylabel('Paid Interest ($)')

# Set the grid style
plt.grid(linestyle='--', linewidth='0.5', color='gray')

# Setting the axes to start at 0
plt.xlim(left=0)

# Show the plot
plt.show()
