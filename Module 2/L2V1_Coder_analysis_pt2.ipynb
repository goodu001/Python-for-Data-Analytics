# %%
import pandas as pd
df = pd.read_csv("survey_data.csv")

# %% [markdown]
# **Goal:** Sort respondents by age, oldest to youngest

# %%
df_sorted_by_age = df.sort_values(by="Age")

# %%
type(df_sorted_by_age)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df_sorted_by_age)
# Out:
# 15620

# %%
df_sorted_by_age.head()
# Out:
#        Age       Gender  NumberOfChildren  CommuteTime  \
# 7419  10.0          NaN               NaN          NaN
# 7341  10.0         male               NaN          NaN
# 8008  11.0         male               NaN          NaN
# 1594  11.0         male               NaN          NaN
# 3472  11.0  genderqueer               NaN          0.0
#
#             CountryOfResidence  HoursSpentLearningToCode  Income  \
# 7419  United States of America                       8.0     NaN
# 7341  United States of America                      28.0     NaN
# 8008            United Kingdom                      10.0     NaN
# 1594  United States of America                       4.0     NaN
# 3472  United States of America                       NaN     NaN
#
#       IsSoftwareDev LanguageAtHome MaritalStatus  MoneySpentLearningToCode  \
# 7419            0.0        English           NaN                       0.0
# 7341            0.0         Slovak           NaN                       0.0
# 8008            0.0        English           NaN                      14.0
# 1594            0.0        English           NaN                       0.0
# 3472            0.0        English           NaN                       0.0
#
#       MonthsSpentProgramming  ResourceBooks  ResourceCoursera  \
# 7419                    24.0            NaN               1.0
# 7341                     2.0            NaN               NaN
# 8008                     6.0            NaN               NaN
# 1594                     3.0            NaN               NaN
# 3472                     1.0            NaN               NaN
#
#       StudentDebtOwed     ID
# 7419              NaN  56723
# 7341              NaN  37786
# 8008              NaN  87769
# 1594              NaN  19537
# 3472              NaN  50947

# %%
df_sorted_by_age = df.sort_values(by="Age", ascending=False) # only include ascending=False for descending sort

# %%
df_sorted_by_age.head()
# Out:
#        Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 5554  86.0    male               NaN          NaN                 Australia
# 560   80.0    male               NaN          NaN              South Africa
# 1846  75.0  female               NaN          NaN  United States of America
# 3927  75.0    male               NaN          0.0  United States of America
# 450   75.0  female               NaN          0.0  United States of America
#
#       HoursSpentLearningToCode    Income  IsSoftwareDev LanguageAtHome  \
# 5554                       NaN       NaN            NaN        English
# 560                       10.0       NaN            0.0        English
# 1846                       6.0       NaN            0.0        English
# 3927                       NaN  125000.0            1.0        English
# 450                        3.0   50000.0            0.0        English
#
#      MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# 5554           NaN                       NaN                     NaN
# 560            NaN                       0.0                     1.0
# 1846           NaN                       NaN                     3.0
# 3927           NaN                       NaN                     NaN
# 450            NaN                       0.0                     0.0
#
#       ResourceBooks  ResourceCoursera  StudentDebtOwed     ID
# 5554            NaN               NaN              NaN  16899
# 560             NaN               NaN              NaN  30553
# 1846            NaN               NaN              NaN  95811
# 3927            NaN               NaN              NaN  42299
# 450             NaN               NaN              NaN  75225

# %%
df_sorted_by_age = df.sort_values(ascending=False, by="Age")

# %%
df_sorted_by_age.head()
# Out:
#        Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 5554  86.0    male               NaN          NaN                 Australia
# 560   80.0    male               NaN          NaN              South Africa
# 1846  75.0  female               NaN          NaN  United States of America
# 3927  75.0    male               NaN          0.0  United States of America
# 450   75.0  female               NaN          0.0  United States of America
#
#       HoursSpentLearningToCode    Income  IsSoftwareDev LanguageAtHome  \
# 5554                       NaN       NaN            NaN        English
# 560                       10.0       NaN            0.0        English
# 1846                       6.0       NaN            0.0        English
# 3927                       NaN  125000.0            1.0        English
# 450                        3.0   50000.0            0.0        English
#
#      MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# 5554           NaN                       NaN                     NaN
# 560            NaN                       0.0                     1.0
# 1846           NaN                       NaN                     3.0
# 3927           NaN                       NaN                     NaN
# 450            NaN                       0.0                     0.0
#
#       ResourceBooks  ResourceCoursera  StudentDebtOwed     ID
# 5554            NaN               NaN              NaN  16899
# 560             NaN               NaN              NaN  30553
# 1846            NaN               NaN              NaN  95811
# 3927            NaN               NaN              NaN  42299
# 450             NaN               NaN              NaN  75225

# %% [markdown]
# **Goal:** Investigate people who study the most for each age

# %%
# sort by age descending, then hours spent studying descending
# find highest studiers by age
columns = ["Age", "HoursSpentLearningToCode"]
order = [False, False]

# %%
sorted_by_age_and_hours = df.sort_values(by=columns, ascending=order)

# %%
type(sorted_by_age_and_hours)
# Out:
# pandas.core.frame.DataFrame

# %%
len(sorted_by_age_and_hours)
# Out:
# 15620

# %%
sorted_by_age_and_hours.head()
# Out:
#        Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 5554  86.0    male               NaN          NaN                 Australia
# 560   80.0    male               NaN          NaN              South Africa
# 1846  75.0  female               NaN          NaN  United States of America
# 450   75.0  female               NaN          0.0  United States of America
# 3927  75.0    male               NaN          0.0  United States of America
#
#       HoursSpentLearningToCode    Income  IsSoftwareDev LanguageAtHome  \
# 5554                       NaN       NaN            NaN        English
# 560                       10.0       NaN            0.0        English
# 1846                       6.0       NaN            0.0        English
# 450                        3.0   50000.0            0.0        English
# 3927                       NaN  125000.0            1.0        English
#
#      MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# 5554           NaN                       NaN                     NaN
# 560            NaN                       0.0                     1.0
# 1846           NaN                       NaN                     3.0
# 450            NaN                       0.0                     0.0
# 3927           NaN                       NaN                     NaN
#
#       ResourceBooks  ResourceCoursera  StudentDebtOwed     ID
# 5554            NaN               NaN              NaN  16899
# 560             NaN               NaN              NaN  30553
# 1846            NaN               NaN              NaN  95811
# 450             NaN               NaN              NaN  75225
# 3927            NaN               NaN              NaN  42299

# %% [markdown]
# **Goal:** Analyze gender breakdown of respondents

# %%
# unique responses
unique_genders = pd.unique(df["Gender"])
print(unique_genders)
# Out:
# ['male' 'female' nan 'genderqueer' 'trans' 'agender']

# %%
# create filtered dataset with only females
female_respondents = df[df["Gender"] == "female"]

# %%
type(female_respondents)
# Out:
# pandas.core.frame.DataFrame

# %%
female_respondents.head()
# Out:
#      Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 3   26.0  female               NaN         45.0  United States of America
# 4   20.0  female               NaN         10.0  United States of America
# 14  31.0  female               NaN        150.0                    Russia
# 15  27.0  female               NaN          0.0  United States of America
# 19  25.0  female               NaN          NaN  United States of America
#
#     HoursSpentLearningToCode   Income  IsSoftwareDev LanguageAtHome  \
# 3                       20.0  43000.0            0.0        English
# 4                       25.0   6000.0            0.0          Khmer
# 14                      10.0      NaN            1.0        Russian
# 15                       4.0  80000.0            1.0        English
# 19                       NaN      NaN            1.0          Hindi
#
#    MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# 3            NaN                     100.0                     3.0
# 4            NaN                    1300.0                    48.0
# 14           NaN                       NaN                   108.0
# 15           NaN                     600.0                    36.0
# 19           NaN                       NaN                     NaN
#
#     ResourceBooks  ResourceCoursera  StudentDebtOwed     ID
# 3             NaN               NaN           7000.0  95684
# 4             NaN               NaN              NaN  39053
# 14            NaN               1.0              NaN  86210
# 15            NaN               1.0              NaN  47416
# 19            NaN               1.0              NaN  86968

# %%
len(female_respondents)
# Out:
# 2840

# %%
len(female_respondents) / len(df)
# Out:
# 0.18181818181818182

# %%
female_respondents["Age"].hist()
# Out:
# <Axes: >

# %%
# age > 30
above_30_respondents = df[df["Age"] > 30]

# %%
above_30_respondents["Age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Goal:** Filter for individuals who are both female and over the age of 30

# %%
females_above_30 = df[(df["Gender"] == "female") & (df["Age"] > 30)] # both conditions must be true

# %%
len(females_above_30)
# Out:
# 1103

# %%
len(females_above_30) < len(female_respondents)
# Out:
# True

# %%
females_above_30.sample(10)
# Out:
#         Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 15437  62.0  female               3.0          NaN  United States of America
# 11214  37.0  female               NaN          NaN  United States of America
# 8031   49.0  female               NaN          NaN  United States of America
# 15508  39.0  female               3.0         60.0                    Serbia
# 13094  34.0  female               1.0         60.0                    Canada
# 5308   31.0  female               NaN          0.0  United States of America
# 15156  46.0  female               1.0          NaN                    Canada
# 13980  54.0  female               2.0          NaN  United States of America
# 13537  36.0  female               2.0         30.0                   Hungary
# 3811   35.0  female               NaN         30.0                    Canada
#
#        HoursSpentLearningToCode   Income  IsSoftwareDev  LanguageAtHome  \
# 15437                      35.0      NaN            0.0         English
# 11214                      10.0      NaN            0.0         English
# 8031                       35.0      NaN            0.0         English
# 15508                       3.0  60000.0            0.0  Serbo-Croatian
# 13094                      10.0  30000.0            0.0          French
# 5308                       10.0  60000.0            1.0         English
# 15156                       7.0      NaN            0.0          French
# 13980                       NaN      NaN            0.0         English
# 13537                      10.0   8000.0            0.0       Hungarian
# 3811                        1.0  50000.0            1.0           Hindi
#
#                          MaritalStatus  MoneySpentLearningToCode  \
# 15437  married or domestic partnership                      50.0
# 11214                              NaN                     200.0
# 8031                               NaN                      20.0
# 15508  married or domestic partnership                       0.0
# 13094  married or domestic partnership                       0.0
# 5308                               NaN                   13500.0
# 15156            single, never married                       0.0
# 13980  married or domestic partnership                       NaN
# 13537  married or domestic partnership                      70.0
# 3811             single, never married                       0.0
#
#        MonthsSpentProgramming  ResourceBooks  ResourceCoursera  \
# 15437                     2.0            NaN               NaN
# 11214                     6.0            NaN               NaN
# 8031                      4.0            NaN               1.0
# 15508                     6.0            NaN               NaN
# 13094                     5.0            NaN               NaN
# 5308                      9.0            NaN               1.0
# 15156                     1.0            NaN               NaN
# 13980                     NaN            NaN               NaN
# 13537                     3.0            NaN               NaN
# 3811                     12.0            NaN               1.0
#
#        StudentDebtOwed     ID
# 15437              NaN  12264
# 11214          25000.0  64145
# 8031           20000.0  84108
# 15508              NaN  78388
# 13094              NaN  79791
# 5308           11000.0  42983
# 15156              NaN  33486
# 13980              NaN  79724
# 13537              NaN  85128
# 3811               NaN  97150

# %%
# female or above 30
females_or_above_30 = df[(df["Gender"] == "female") | (df["Age"] > 30)]

# %%
females_or_above_30.sample(10)
# Out:
#         Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 13265  31.0    male               1.0          NaN                   Germany
# 6797   42.0    male               NaN          NaN                     Spain
# 4497   50.0    male               NaN         50.0            United Kingdom
# 13124  38.0    male               3.0         10.0                    Mexico
# 12500  22.0  female               NaN         90.0                     India
# 7472   31.0    male               NaN          0.0  United States of America
# 3343   32.0  female               NaN          0.0                    Russia
# 1571   37.0  female               NaN          NaN  United States of America
# 6056   38.0    male               NaN         40.0  United States of America
# 14751  36.0  female               2.0         20.0  United States of America
#
#        HoursSpentLearningToCode   Income  IsSoftwareDev LanguageAtHome  \
# 13265                       5.0      NaN            0.0         German
# 6797                       35.0      NaN            0.0        Spanish
# 4497                       15.0  10000.0            0.0        English
# 13124                       5.0  24000.0            1.0        Spanish
# 12500                       5.0  15372.0            1.0          Hindi
# 7472                        8.0  85000.0            1.0        English
# 3343                        4.0  10000.0            1.0        Russian
# 1571                       10.0      NaN            0.0        Spanish
# 6056                       10.0  50000.0            0.0        English
# 14751                       4.0  46000.0            0.0        English
#
#                          MaritalStatus  MoneySpentLearningToCode  \
# 13265  married or domestic partnership                       0.0
# 6797                               NaN                     250.0
# 4497                               NaN                    1500.0
# 13124  married or domestic partnership                     300.0
# 12500            single, never married                     250.0
# 7472                               NaN                       0.0
# 3343                               NaN                     200.0
# 1571                               NaN                      20.0
# 6056                               NaN                     100.0
# 14751  married or domestic partnership                      50.0
#
#        MonthsSpentProgramming  ResourceBooks  ResourceCoursera  \
# 13265                    18.0            NaN               NaN
# 6797                      2.0            NaN               1.0
# 4497                      8.0            NaN               NaN
# 13124                     NaN            NaN               NaN
# 12500                     7.0            NaN               1.0
# 7472                     36.0            NaN               NaN
# 3343                     60.0            NaN               1.0
# 1571                      2.0            NaN               1.0
# 6056                      3.0            NaN               NaN
# 14751                     2.0            NaN               NaN
#
#        StudentDebtOwed     ID
# 13265          15000.0  47941
# 6797               NaN  95490
# 4497               NaN  49737
# 13124              NaN  95032
# 12500              NaN  94535
# 7472          138000.0  90461
# 3343               NaN  80577
# 1571            6000.0  56310
# 6056               NaN  24459
# 14751         125000.0  43409

# %%
df
# Out:
#         Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# 0      28.0    male               NaN         35.0  United States of America
# 1      22.0    male               NaN         90.0  United States of America
# 2      19.0    male               NaN         45.0  United States of America
# 3      26.0  female               NaN         45.0  United States of America
# 4      20.0  female               NaN         10.0  United States of America
# ...     ...     ...               ...          ...                       ...
# 15615  28.0    male               1.0          7.0  United States of America
# 15616  43.0    male               3.0          3.0                    Canada
# 15617  43.0    male               2.0         15.0  United States of America
# 15618  37.0    male               1.0        120.0                    Canada
# 15619  30.0    male               2.0         45.0              South Africa
#
#        HoursSpentLearningToCode    Income  IsSoftwareDev LanguageAtHome  \
# 0                          30.0   32000.0            0.0        English
# 1                          30.0   15000.0            0.0        English
# 2                          20.0   48000.0            0.0        English
# 3                          20.0   43000.0            0.0        English
# 4                          25.0    6000.0            0.0          Khmer
# ...                         ...       ...            ...            ...
# 15615                      20.0  200000.0            0.0        English
# 15616                       3.0  200000.0            0.0        English
# 15617                       6.0  200000.0            0.0        English
# 15618                      40.0  200000.0            0.0        English
# 15619                       4.0  200000.0            0.0        English
#
#                          MaritalStatus  MoneySpentLearningToCode  \
# 0      married or domestic partnership                       0.0
# 1                                  NaN                      20.0
# 2                                  NaN                      50.0
# 3                                  NaN                     100.0
# 4                                  NaN                    1300.0
# ...                                ...                       ...
# 15615  married or domestic partnership                    1400.0
# 15616                         divorced                       0.0
# 15617  married or domestic partnership                     300.0
# 15618  married or domestic partnership                     200.0
# 15619  married or domestic partnership                     300.0
#
#        MonthsSpentProgramming  ResourceBooks  ResourceCoursera  \
# 0                         1.0            NaN               1.0
# 1                         2.0            NaN               1.0
# 2                        24.0            NaN               NaN
# 3                         3.0            NaN               NaN
# 4                        48.0            NaN               NaN
# ...                       ...            ...               ...
# 15615                     7.0            NaN               NaN
# 15616                     8.0            NaN               NaN
# 15617                     6.0            NaN               NaN
# 15618                   360.0            NaN               1.0
# 15619                     6.0            NaN               NaN
#
#        StudentDebtOwed     ID
# 0              20000.0  92257
# 1                  NaN  43079
# 2                  NaN  67780
# 3               7000.0  95684
# 4                  NaN  39053
# ...                ...    ...
# 15615          12000.0  51896
# 15616              NaN  47456
# 15617              NaN  59724
# 15618              NaN  58050
# 15619              NaN  17145
#
# [15620 rows x 16 columns]

# %%
indexed_df = df.set_index("ID")

# %%
indexed_df.head()
# Out:
#         Age  Gender  NumberOfChildren  CommuteTime        CountryOfResidence  \
# ID
# 92257  28.0    male               NaN         35.0  United States of America
# 43079  22.0    male               NaN         90.0  United States of America
# 67780  19.0    male               NaN         45.0  United States of America
# 95684  26.0  female               NaN         45.0  United States of America
# 39053  20.0  female               NaN         10.0  United States of America
#
#        HoursSpentLearningToCode   Income  IsSoftwareDev LanguageAtHome  \
# ID
# 92257                      30.0  32000.0            0.0        English
# 43079                      30.0  15000.0            0.0        English
# 67780                      20.0  48000.0            0.0        English
# 95684                      20.0  43000.0            0.0        English
# 39053                      25.0   6000.0            0.0          Khmer
#
#                          MaritalStatus  MoneySpentLearningToCode  \
# ID
# 92257  married or domestic partnership                       0.0
# 43079                              NaN                      20.0
# 67780                              NaN                      50.0
# 95684                              NaN                     100.0
# 39053                              NaN                    1300.0
#
#        MonthsSpentProgramming  ResourceBooks  ResourceCoursera  \
# ID
# 92257                     1.0            NaN               1.0
# 43079                     2.0            NaN               1.0
# 67780                    24.0            NaN               NaN
# 95684                     3.0            NaN               NaN
# 39053                    48.0            NaN               NaN
#
#        StudentDebtOwed
# ID
# 92257          20000.0
# 43079              NaN
# 67780              NaN
# 95684           7000.0
# 39053              NaN

# %%
# pull info for ID 25447
indexed_df.loc[25447]
# Out:
# Age                                          35.0
# Gender                                       male
# NumberOfChildren                              NaN
# CommuteTime                                   NaN
# CountryOfResidence                     Bangladesh
# HoursSpentLearningToCode                     10.0
# Income                                        NaN
# IsSoftwareDev                                 0.0
# LanguageAtHome                            Bengali
# MaritalStatus               single, never married
# MoneySpentLearningToCode                    500.0
# MonthsSpentProgramming                        6.0
# ResourceBooks                                 NaN
# ResourceCoursera                              NaN
# StudentDebtOwed                               NaN
# Name: 25447, dtype: object

# %%
response_1000 = indexed_df.iloc[1000]

# %%
type(response_1000)
# Out:
# pandas.core.series.Series

# %%
response_1000
# Out:
# Age                                             25.0
# Gender                                          male
# NumberOfChildren                                 NaN
# CommuteTime                                      NaN
# CountryOfResidence          United States of America
# HoursSpentLearningToCode                        20.0
# Income                                           NaN
# IsSoftwareDev                                    1.0
# LanguageAtHome                               English
# MaritalStatus                                    NaN
# MoneySpentLearningToCode                      2000.0
# MonthsSpentProgramming                          48.0
# ResourceBooks                                    NaN
# ResourceCoursera                                 1.0
# StudentDebtOwed                              45000.0
# Name: 66949, dtype: object

# %%
response_1000.index
# Out:
# Index(['Age', 'Gender', 'NumberOfChildren', 'CommuteTime',
#        'CountryOfResidence', 'HoursSpentLearningToCode', 'Income',
#        'IsSoftwareDev', 'LanguageAtHome', 'MaritalStatus',
#        'MoneySpentLearningToCode', 'MonthsSpentProgramming', 'ResourceBooks',
#        'ResourceCoursera', 'StudentDebtOwed'],
#       dtype='object')

# %%
response_1000["Age"]
# Out:
# np.float64(25.0)

# %%
# investigate 5 rows starting at 8664
range_of_rows = indexed_df.iloc[8664:8669] # called slicing!

# %%
type(range_of_rows)
# Out:
# pandas.core.frame.DataFrame

# %%
range_of_rows
# Out:
#        Age Gender  NumberOfChildren  CommuteTime CountryOfResidence  \
# ID
# 60318  NaN    NaN               NaN          NaN                NaN
# 94655  NaN    NaN               NaN          NaN                NaN
# 92202  NaN    NaN               NaN          NaN                NaN
# 31166  NaN    NaN               NaN          NaN                NaN
# 84251  NaN    NaN               NaN          NaN                NaN
#
#        HoursSpentLearningToCode  Income  IsSoftwareDev LanguageAtHome  \
# ID
# 60318                      10.0     NaN            0.0            NaN
# 94655                      20.0     NaN            0.0            NaN
# 92202                       5.0     NaN            0.0            NaN
# 31166                      20.0     NaN            0.0            NaN
# 84251                       5.0     NaN            0.0            NaN
#
#       MaritalStatus  MoneySpentLearningToCode  MonthsSpentProgramming  \
# ID
# 60318           NaN                       0.0                     NaN
# 94655           NaN                       0.0                     7.0
# 92202           NaN                       0.0                     0.0
# 31166           NaN                       0.0                    12.0
# 84251           NaN                       0.0                     3.0
#
#        ResourceBooks  ResourceCoursera  StudentDebtOwed
# ID
# 60318            NaN               NaN              NaN
# 94655            NaN               NaN              NaN
# 92202            NaN               NaN              NaN
# 31166            NaN               1.0              NaN
# 84251            NaN               NaN              NaN
